# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import scipy.stats as stats
import numpy as np

# %% [markdown]
# # Importing data base

# %%
df=pd.read_csv('2015.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
#Visualizing using heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.nunique().to_frame('No of unique values')
# Out:
#                                No of unique values
# Country                                        158
# Region                                          10
# Happiness Rank                                 157
# Happiness Score                                157
# Standard Error                                 153
# Economy (GDP per Capita)                       158
# Family                                         158
# Health (Life Expectancy)                       157
# Freedom                                        158
# Trust (Government Corruption)                  157
# Generosity                                     158
# Dystopia Residual                              158

# %%
# Checking the value count of each column
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
#
#
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
#
#
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
#
#
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# ...

# %% [markdown]
# ### Description of data

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# we can see that the men is almost as same as median i all the case so tere is less chances of skewness

# %% [markdown]
# ### LMplot

# %% [markdown]
# The lmplot function is commonly used to visualize the relationship between two variables and fit a linear regression model to the data. It is particularly useful for exploring and understanding the potential linear relationship between variables, identifying outliers, and assessing the model's goodness of fit.

# %%
sns.lmplot(x='Happiness Rank',y='Happiness Score',data=df,palette='Colorblind')

# %% [markdown]
# We can see that happiness rank and Happiness score have very high negative correlation

# %%
sns.lmplot(x='Standard Error',y='Happiness Score',data=df,palette='Colorblind')

# %% [markdown]
# WE can see that Standard Error and Hapiness score have negative correlation.It is facto not directly contributing to the happiness score so we can drop it

# %%
sns.lmplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df,palette='Colorblind')

# %% [markdown]
# IT is showing a positive correlatio between the target variable and feature

# %%
sns.lmplot(x='Family',y='Happiness Score',data=df,palette='Colorblind')

# %% [markdown]
# IT is showing a positive correlatio between the target variable and feature

# %%
sns.lmplot(x='Health (Life Expectancy)',y='Happiness Score',data=df,palette='Colorblind')

# %%
sns.lmplot(x='Freedom',y='Happiness Score',data=df,palette='Colorblind')

# %% [markdown]
# IT is showing a positive correlatio between the target variable and feature

# %%
sns.lmplot(x='Trust (Government Corruption)',y='Happiness Score',data=df,palette='Colorblind')

# %% [markdown]
# IT is showing a positive correlatio between the target variable and feature

# %%
sns.lmplot(x='Dystopia Residual',y='Happiness Score',data=df,palette='Colorblind')

# %% [markdown]
# IT is showing a positive correlatio between the target variable and feature

# %%
# dropping standard error
df=df.drop('Standard Error',axis=1)

# %% [markdown]
# ### Regplot

# %% [markdown]
# The main purpose of regplot is to examine the linear relationship between two variables and understand the trend or pattern in the data. It is particularly useful for determining if there is a correlation between the variables and assessing the strength and direction of that correlation.

# %%
# for this we need to seperate object and int and flot


string_columns = df.select_dtypes(include='object')

numeric_columns = df.select_dtypes(include=['float64', 'int64'])

print('String  : ',string_columns.columns.tolist())

print('Numeric  : ',numeric_columns.columns.tolist())
# Out:
# String  :  ['Country', 'Region']
# Numeric  :  ['Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %%
plt.figure(figsize=(20,25))
p=1
for i in numeric_columns:
    if p < 17:
        plt.subplot(5,4,p)
        sns.regplot(x='Happiness Score',y=i,data=df,color='r')
        plt.xlabel('Happiness Score')
        plt.ylabel(i)
    p+=1
plt.show()

# %% [markdown]
# ### ScatterPlot

# %%
plt.figure(figsize=(20,25))
p=1
for i in numeric_columns:
    if p < 17:
        plt.subplot(5,4,p)
        sns.scatterplot(x='Happiness Score',y=i,data=df,color='r')
        plt.xlabel('Happiness Score')
        plt.ylabel(i)
    p+=1
plt.show()

# %% [markdown]
# ### pair plot

# %%
sns.pairplot(data=df,palette='Dark')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# ...

# %% [markdown]
# ## Checking the Outliers

# %%
plt.figure(figsize=(20,25))
p=1
for i in numeric_columns:
    if p<=13:
        plt.subplot(5,2,p)
        sns.boxplot(numeric_columns[i],palette='bright')
        plt.xlabel(i)
    p+=1
plt.show()

# %% [markdown]
# We can see that family, trust(government Corruption),generosity and Dystopia residual have outliers

# %% [markdown]
# ### Zscore method

# %%
from scipy.stats import zscore
out_features=df[['Family','Trust (Government Corruption)','Generosity','Dystopia Residual']]
z=np.abs(zscore(out_features))
z
# Out:
#        Family  Trust (Government Corruption)  Generosity  Dystopia Residual
# 0    1.320281                       2.309652    0.471040           0.758258
# 1    1.514458                       0.016480    1.575856           1.092857
# 2    1.361054                       2.842774    0.824293           0.712335
# 3    1.251922                       1.852081    0.868638           0.663893
# 4    1.221204                       1.555725    1.748563           0.639337
# ..        ...                            ...         ...                ...
# 153  0.800520                       3.413922    0.087228           2.588925
# 154  2.346860                       0.529210    0.433117           0.843967
# 155  1.901086                       0.381419    1.856891           3.208430
# 156  2.118467                       0.357715    0.316950           0.481985
# 157  3.134725                       0.301803    0.558153           0.963612
#
# [158 rows x 4 columns]

# %%
#thrash hold value 3 coz by default it ie -3 to +3 as 99.7% data is present between them in bell shape curve
np.where(z>3)
# Out:
# (array([ 27, 128, 147, 153, 155, 157], dtype=int64),
#  array([1, 2, 0, 1, 3, 0], dtype=int64))

# %%
# checking if the valu is greater tha 3 or not taking random row and respective column from above
z.iloc[27,1]
# Out:
# 3.1646194851713774

# %%
# checking if the valu is greater tha 3 or not taking random row and respective column from above
z.iloc[157,0]
# Out:
# 3.1347248549706186

# %%
# now removing thedata above zscore and dreating a new DF
df1=df[(z<3).all(axis=1)]
df1.shape
# Out:
# (152, 11)

# %%
#shape of old and new data frame
print('Old Data Frame -',df.shape[0])
print('New Data Frame -',df1.shape[0])
# Out:
# Old Data Frame - 158
# New Data Frame - 152

# %%
# loss of data from ols to new
print(' Loss of Data - ',(df.shape[0]-df1.shape[0]))
print('\n')
print(' Loss of Data in percentage - ',((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
#  Loss of Data -  6
#
#
#  Loss of Data in percentage -  3.79746835443038

# %% [markdown]
# This much dada loss is acceptable now we will check IQR method

# %% [markdown]
# ### IQR

# %%
# Now we will use IQR method


#1st quar=ntile
q1=out_features.quantile(0.25)
 

#3rd quantile
q3=out_features.quantile(0.75)

#IQR
IQR=q3-q1

# %%
df2=df[~((df < (q1-1.5*IQR))|(df>(q3+1.5*IQR))).any(axis=1)]

# %%
df2
# Out:
#           Country                           Region  Happiness Rank  \
# 1         Iceland                   Western Europe               2
# 4          Canada                    North America               5
# 6     Netherlands                   Western Europe               7
# 9       Australia        Australia and New Zealand              10
# 10         Israel  Middle East and Northern Africa              11
# ..            ...                              ...             ...
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 154         Benin               Sub-Saharan Africa             155
# 156       Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 1              7.561                   1.30232  1.40223
# ...

# %%
df2.shape
# Out:
# (136, 11)

# %%
# loss of data from ols to new
print(' Loss of Data - ',(df.shape[0]-df2.shape[0]))
print('\n')
print(' Loss of Data in percentage - ',((df.shape[0]-df2.shape[0])/df.shape[0])*100)
# Out:
#  Loss of Data -  22
#
#
#  Loss of Data in percentage -  13.924050632911392

# %% [markdown]
# The data loss here is much more than compare to Zscore so we are going to use zscore

# %%
df=df1

# %%
#seperating string and integer from new df


string_col = df.select_dtypes(include='object')

numeric_col = df.select_dtypes(include=['float64', 'int64'])

print('String  : ',string_columns.columns.tolist())

print('Numeric  : ',numeric_columns.columns.tolist())
# Out:
# String  :  ['Country', 'Region']
# Numeric  :  ['Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %% [markdown]
# ### Checking how the data is bing distributed in each column

# %%
plt.figure(figsize=(20,25),facecolor='green')
plotnumber=1

for i in numeric_col:   
    if plotnumber<=5:
        plt.subplot(6,4,plotnumber)
        sns.distplot(df[i],color='m')
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# ### Encoding Categorical columns

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1)) 
        
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  \
# 0      131.0     9.0               1            7.587
# 1       57.0     9.0               2            7.561
# 2       36.0     9.0               3            7.527
# 3      103.0     9.0               4            7.522
# 4       24.0     5.0               5            7.427
# ..       ...     ...             ...              ...
# 150     65.0     8.0             151            3.655
# 151     20.0     8.0             152            3.587
# 152      0.0     7.0             153            3.575
# 154     13.0     8.0             155            3.340
# 156     21.0     8.0             157            2.905
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
# Now we will be ckecking for skewness

# %% [markdown]
# ## Skewness

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.086220
# Happiness Rank                   0.008526
# Happiness Score                  0.165587
# Economy (GDP per Capita)        -0.401110
# Family                          -0.815356
# Health (Life Expectancy)        -0.733453
# Freedom                         -0.406211
# Trust (Government Corruption)    1.287270
# Generosity                       0.646579
# Dystopia Residual               -0.045578
# dtype: float64

# %%
#removing the skewness using yeojhonson

# %%
df['Trust (Government Corruption)'],ambda_=stats.yeojohnson(df['Trust (Government Corruption)'])
df['Family'],ambda_=stats.yeojohnson(df['Family']) 
df['Generosity'],ambda_=stats.yeojohnson(df['Generosity']) 
df['Health (Life Expectancy)'],ambda_=stats.yeojohnson(df['Health (Life Expectancy)'])

# %%
#now  we will check if the skewness is removed or not

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.086220
# Happiness Rank                   0.008526
# Happiness Score                  0.165587
# Economy (GDP per Capita)        -0.401110
# Family                          -0.149268
# Health (Life Expectancy)        -0.184207
# Freedom                         -0.406211
# Trust (Government Corruption)    0.179115
# Generosity                       0.022444
# Dystopia Residual               -0.045578
# dtype: float64

# %%
# now we will confirm it using displot

# %%
sns.distplot(df['Trust (Government Corruption)'],kde_kws={'shade':True},hist=False)
plt.show()

# %%
sns.distplot(df['Family'],kde_kws={'shade':True},hist=False)
plt.show()

# %%
sns.distplot(df['Health (Life Expectancy)'],kde_kws={'shade':True},hist=False)
plt.show()

# %%
sns.distplot(df['Generosity'],kde_kws={'shade':True},hist=False)
plt.show()

# %%
# we can see in all the above plots that skewnes is removed

# %% [markdown]
# ### Correlation with the target variable and independent variables

# %%
# correlation between features
df.corr()
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.003610       -0.130967
# Region                         0.003610  1.000000        0.192989
# Happiness Rank                -0.130967  0.192989        1.000000
# Happiness Score                0.124475 -0.153580       -0.992880
# Economy (GDP per Capita)       0.045929 -0.236321       -0.773363
# Family                         0.176994 -0.108298       -0.753043
# Health (Life Expectancy)       0.028543 -0.264547       -0.757734
# Freedom                        0.097270  0.087694       -0.575727
# Trust (Government Corruption)  0.011095  0.216694       -0.359978
# Generosity                     0.112214  0.315783       -0.208219
# Dystopia Residual              0.051158 -0.053742       -0.516071
#
#                                Happiness Score  Economy (GDP per Capita)  \
# Country                               0.124475                  0.045929
# ...

# %% [markdown]
# We can also use heta map for the same

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df.corr(),linewidth=0.2,fmt='.2f',linecolor='black',annot=True,cmap='Spectral')
plt.xlabel('Figures',fontsize=14)
plt.ylabel('Feature_name',fontsize=14)
plt.title('Descriptive Graph',fontsize=20)
plt.show()

# %%
#Checking the correlation of target variable only

df.corr()['Happiness Score'].sort_values(ascending=False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.772257
# Family                           0.755751
# Health (Life Expectancy)         0.754684
# Freedom                          0.588780
# Dystopia Residual                0.518700
# Trust (Government Corruption)    0.388805
# Generosity                       0.232692
# Country                          0.124475
# Region                          -0.153580
# Happiness Rank                  -0.992880
# Name: Happiness Score, dtype: float64

# %% [markdown]
# Economy (GDP per Capita) have gigh correlation with the target variable

# %%
#Visualizing the correlation between the features and the label using bar plot

plt.figure(figsize=(22,7))
df.corr()['Happiness Score'].sort_values(ascending=False).drop(['Happiness Score']).plot(kind='bar',color='y')
plt.title("Correlation between features and label using bar plot",fontsize=20)
plt.xlabel("Features")
plt.ylabel("Target variable")
plt.show()

# %% [markdown]
# ### Seperating features and label

# %%
x=df.drop(['Happiness Score'],axis=1)
y=df["Happiness Score"]

# %%
print("Feature dimensions:",x.shape)
print("Target dimensions:",y.shape)
# Out:
# Feature dimensions: (152, 10)
# Target dimensions: (152,)

# %% [markdown]
# ### Feature scaling using standard scalarisation

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#       Country    Region  Happiness Rank  Economy (GDP per Capita)    Family  \
# 0    1.264880  1.304355       -1.720892                  1.381206  1.667619
# 1   -0.421627  1.304355       -1.698410                  1.139208  2.021011
# 2   -0.900230  1.304355       -1.675928                  1.198712  1.740153
# 3    0.626742  1.304355       -1.653446                  1.541758  1.547968
# 4   -1.173718 -0.024033       -1.630965                  1.200793  1.494996
# ..        ...       ...             ...                       ...       ...
# 147 -0.239302  0.972258        1.651376                 -1.011204 -1.053494
# 148 -1.264880  0.972258        1.673858                 -1.543604 -0.784363
# 149 -1.720693  0.640161        1.696339                 -1.385081 -2.091490
# 150 -1.424415  0.972258        1.741303                 -1.470304 -2.015033
# 151 -1.242090  0.972258        1.786266                 -2.167470 -1.911546
#
# ...

# %% [markdown]
# ### Checking Variance Inflation Factor

# %%
#Checking Vif in every scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#    VIF values                       Features
# 0    1.082104                        Country
# 1    1.541573                         Region
# 2   70.331851                 Happiness Rank
# 3   13.333597       Economy (GDP per Capita)
# 4    5.622270                         Family
# 5    7.284614       Health (Life Expectancy)
# 6    3.300128                        Freedom
# 7    1.689746  Trust (Government Corruption)
# 8    2.116332                     Generosity
# 9   15.957249              Dystopia Residual

# %% [markdown]
# VIF = 1: Indicates no multicollinearity. The predictor variable is not correlated with other variables in the model.
# VIF > 1 and VIF < 5: Suggests moderate multicollinearity. The predictor variable is moderately correlated with other variables.
# VIF >= 5: Indicates high multicollinearity. The predictor variable is highly correlated with other variables, and its coefficient estimates may be unreliable

# %%
# removing the Happiness rank
x = x.drop("Happiness Rank", axis=1)

# %%
#Checking Vif in every scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#    VIF values                       Features
# 0    1.051323                        Country
# 1    1.308306                         Region
# 2    4.430190       Economy (GDP per Capita)
# 3    2.177659                         Family
# 4    3.782172       Health (Life Expectancy)
# 5    1.946893                        Freedom
# 6    1.379725  Trust (Government Corruption)
# 7    1.489869                     Generosity
# 8    1.047777              Dystopia Residual

# %% [markdown]
# ### Modelling

# %%
#Importing libraries

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Creating train test split

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum R2 score is:",maxAccu,"on random state",maxRS)
# Out:
# Maximum R2 score is: 0.9983367613536718 on random state 97

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
#Importing all the regressor models

from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_LR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score: 0.9983367613536718
# R2 score on training data: 99.59411048546592
# Mean Absolute Error: 0.03769606565042026
# Mean Squared Error: 0.002009994450772329
# Root Mean Squared Error: 0.04483296165515199

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_RFR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_RFR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2 score: 0.8573472822841258
# R2 score on training data: 98.69376668981349
# Mean Absolute Error: 0.31474673913043455
# Mean Squared Error: 0.1723932832065217
# Root Mean Squared Error: 0.4152027013478136

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print("R2 score:",r2_score(y_test,pred_knn))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error:",mean_squared_error(y_test,pred_knn))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2 score: 0.9072289771713922
# R2 score on training data: 93.283487820795
# Mean Absolute Error: 0.2466391304347826
# Mean Squared Error: 0.11211213826086949
# Root Mean Squared Error: 0.334831507270253

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_GBR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_GBR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2 score: 0.9186474846017653
# R2 score on training data: 99.9517347133836
# Mean Absolute Error: 0.22804394337731507
# Mean Squared Error: 0.09831307423489878
# Root Mean Squared Error: 0.31354915760514934

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print("R2 score:",r2_score(y_test,pred_lasso))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error:",mean_squared_error(y_test,pred_lasso))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2 score: -0.000393188480390938
# R2 score on training data: 0.0
# Mean Absolute Error: 0.9220328137817885
# Mean Squared Error: 1.2089574529037104
# Root Mean Squared Error: 1.0995260128363087

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print("R2 score:",r2_score(y_test,pred_rd))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_rd))
print("Mean Squared Error:",mean_squared_error(y_test,pred_rd))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2 score: 0.9982656981803719
# R2 score on training data: 99.59024171511045
# Mean Absolute Error: 0.038657417935775776
# Mean Squared Error: 0.002095873037289272
# Root Mean Squared Error: 0.04578070595009728

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_svr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_svr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_svr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# R2 score: 0.9580757338147214
# R2 score on training data: 98.99397087578197
# Mean Absolute Error: 0.1662049161957381
# Mean Squared Error: 0.05066473327272656
# Root Mean Squared Error: 0.2250882788434941

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_etr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_etr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_etr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# R2 score: 0.8734680205968592
# R2 score on training data: 100.0
# Mean Absolute Error: 0.28490413043478224
# Mean Squared Error: 0.15291165642826074
# Root Mean Squared Error: 0.391039200628608

# %%
from sklearn.model_selection import cross_val_score

# %%
#Checking cvs for every model
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.96652725 0.86375655 0.8799255  0.81443313 0.9276193 ]
# 0.8904523464876325
# Difference between R2 score and CVS is: 10.788441486603928

# %%
score=cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [-8.19899998 -0.84939881 -0.83245829 -2.7830686  -6.06160659]
# -3.745106454945077
# Difference between R2 score and CVS is: 460.24537372292025

# %%
score=cross_val_score(knn,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_knn)-score.mean())*100)
# Out:
# [-10.27302805  -2.99767899  -2.45352716  -8.04927902  -5.3795738 ]
# -5.830617403432962
# Difference between R2 score and CVS is: 673.7846380604354

# %%
score=cross_val_score(GBR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [-4.26177709 -0.3534553  -1.51724655 -2.68796481 -3.97115907]
# -2.558320564701719
# Difference between R2 score and CVS is: 347.69680493034843

# %%
score=cross_val_score(lasso,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_lasso)-score.mean())*100)
# Out:
# [-38.6679694  -11.48068188  -0.35121051 -34.90294813 -27.69082817]
# -22.61872761773089
# Difference between R2 score and CVS is: 2261.83344292505

# %%
score=cross_val_score(rd,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_rd)-score.mean())*100)
# Out:
# [0.96827705 0.856169   0.88234476 0.82394579 0.91591239]
# 0.8893297980343071
# Difference between R2 score and CVS is: 10.893590014606481

# %%
score=cross_val_score(svr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_svr)-score.mean())*100)
# Out:
# [-10.14249196   0.11872845   0.73582762  -0.43769346  -5.28891767]
# -3.002909402446428
# Difference between R2 score and CVS is: 396.09851362611494

# %%
score=cross_val_score(etr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_etr)-score.mean())*100)
# Out:
# [-7.13169008 -0.2548722  -0.99667795 -2.31330301 -5.59430179]
# -3.2581690040672493
# Difference between R2 score and CVS is: 413.1637024664109

# %%
#From the difference we conclude Ridge is the best performing model

# %% [markdown]
# # HyperParameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param = {
    'alpha': [0.1, 1.0, 10.0],
    'fit_intercept': [True, False],
    'normalize': [True, False],
    'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg'],
    'max_iter': [None, 100, 1000],
    'random_state': [42]
}

# %%
gscv=GridSearchCV(Ridge(),param,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1.0, 10.0],
#                          'fit_intercept': [True, False],
#                          'max_iter': [None, 100, 1000],
#                          'normalize': [True, False], 'random_state': [42],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                     'sparse_cg']})

# %%
gscv.best_params_
# Out:
# {'alpha': 0.1,
#  'fit_intercept': True,
#  'max_iter': None,
#  'normalize': False,
#  'random_state': 42,
#  'solver': 'sparse_cg'}

# %%
Model=Ridge(alpha= 0.1,
 fit_intercept= True,
 max_iter= None,
 normalize= False,
 random_state= 42,
 solver= 'sparse_cg')

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print("R2 score:",r2_score(y_test,pred))
print("Mean Absolute Error:",mean_absolute_error(y_test,pred))
print("Mean Squared Error:",mean_squared_error(y_test,pred))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 score: 0.9983512890110859
# Mean Absolute Error: 0.03757536876839341
# Mean Squared Error: 0.001992438034048983
# Root Mean Squared Error: 0.04463673413287517

# %%
import pickle
filename='Medical Cost Personal Insurance Project.pkl'
pickle.dump(Model,open(filename, 'wb'))  #saved model

# %%
#loading the model

loaded_model=pickle.load(open('Medical Cost Personal Insurance Project.pkl','rb'))  #read binary mode
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 99.83512890110859

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","original"])

# %%
conclusion_vertical = conclusion.transpose()
conclusion_vertical
# Out:
#     Predicted  original
# 0    4.236301     4.271
# 1    4.484863     4.518
# 2    4.914682     4.874
# 3    5.559371     5.548
# 4    5.660187     5.709
# 5    6.823664     6.810
# 6    5.844298     5.855
# 7    5.521239     5.474
# 8    6.790394     6.853
# 9    4.432866     4.514
# 10   7.334650     7.378
# 11   6.242720     6.269
# 12   4.186225     4.218
# 13   4.509951     4.571
# 14   5.109761     5.129
# 15   5.837513     5.828
# 16   4.711781     4.681
# 17   3.818404     3.896
# 18   5.258747     5.268
# 19   4.011208     3.995
# 20   5.481064     5.429
# 21   7.591619     7.587
# 22   6.841205     6.867
# 23   7.234056     7.200
# 24   3.567481     3.587
# 25   5.663845     5.716
# 26   4.210446     4.252
# 27   5.926482     5.960
# 28   5.674020     5.689
# 29   6.805631     6.750
# 30   3.684845     3.667
# 31   4.822170     4.800
# 32   4.905345     4.885
# 33   5.980923     5.948
# 34   4.620052     4.507
# 35   3.659866     3.681
# 36   4.524329     4.550
# ...
